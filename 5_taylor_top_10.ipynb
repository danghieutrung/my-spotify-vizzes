# %%
pip install pandas

# %%
import pandas as pd

df = pd.read_csv('data/0_preprocessed.csv')
df
# Out:
#             timestamp  duration                song         artist  \
# 0       7/5/2019 3:00      2.45             7 rings  Ariana Grande
# 1       7/5/2019 3:01      1.29      All Falls Down    Alan Walker
# 2       7/5/2019 3:05      3.67        I Don't Care     Ed Sheeran
# 3       7/5/2019 3:08      3.30    Beautiful People     Ed Sheeran
# 4       7/5/2019 3:12      3.32      All Falls Down    Alan Walker
# ...               ...       ...                 ...            ...
# 47672  9/4/2024 13:36      3.15       The Lazy Song     Bruno Mars
# 47673  9/4/2024 14:35      2.64          Part Of Me     Katy Perry
# 47674  9/5/2024 13:50      0.00  Beautiful In White    Shane Filan
# 47675  9/5/2024 16:08      0.07  Beautiful In White    Shane Filan
# 47676  9/5/2024 16:13      4.34      Nơi Này Có Anh  Sơn Tùng M-TP
#
#                                         album  \
# 0                               thank u, next
# 1                              All Falls Down
# ...

# %%
taylor_top_10_list = [
 'Sparks Fly',
 'Enchanted',
 'Begin Again',
 'If This Was A Movie',
 'Treacherous',
 'I\'d Lie',
 'I Almost Do',
 'Everything Has Changed',
 'Fearless',
 'Superman'
]

# %%
df_taylor = df[df['artist'] == 'Taylor Swift']
df_taylor = df_taylor.groupby(['song', 'album'])['duration'].sum().reset_index().sort_values(by='duration', ascending=False)
df_taylor['duration'] = df_taylor['duration'].astype(int)
df_taylor
# Out:
#                                                   song      album  duration
# 32                                           Enchanted  Speak Now      8423
# 86                                          Sparks Fly  Speak Now      6485
# 33                              Everything Has Changed        Red      3942
# 14                                         Begin Again        Red      3400
# 116                                        Treacherous        Red      2715
# ..                                                 ...        ...       ...
# 115                                           Timeless  Speak Now         0
# 21   Carolina - From The Motion Picture “Where The ...   Carolina         0
# 119                                     Vigilante Shit  Midnights         0
# 30                                         Dear Reader  Midnights         0
# 151                                             willow   evermore         0
#
# [152 rows x 3 columns]

# %%
taylor_top_10 = pd.DataFrame({
  'n': [i for i in range(1,11)],
  'most_played': df_taylor.head(10)['song'].tolist(),
  'mins': df_taylor.head(10)['duration'].tolist(),
  'fav_10': taylor_top_10_list
})

taylor_top_10
# Out:
#     n             most_played  mins                  fav_10
# 0   1               Enchanted  8423              Sparks Fly
# 1   2              Sparks Fly  6485               Enchanted
# 2   3  Everything Has Changed  3942             Begin Again
# 3   4             Begin Again  3400     If This Was A Movie
# 4   5             Treacherous  2715             Treacherous
# 5   6             I Almost Do  2493                 I'd Lie
# 6   7        Back To December  2453             I Almost Do
# 7   8     If This Was A Movie  2434  Everything Has Changed
# 8   9              Love Story  1965                Fearless
# 9  10                Fearless  1962                Superman

# %%
my_fav_10_ranked = [50,16,42,218,63,207,117,130,41,220]
rs_top_10 = [
  "All Too Well",
  "New Romantics",
  "mirrorball",
  "Delicate",
  "august",
  "Long Live",
  "Lover",
  "Blank Space",
  "majorie",
  "Dear John"
]

# %%
taylor_top_10['RS_ranked'] = my_fav_10_ranked
taylor_top_10['RS_top_10'] = rs_top_10
taylor_top_10
# Out:
#     n             most_played  mins                  fav_10  RS_ranked  \
# 0   1               Enchanted  8423              Sparks Fly         50
# 1   2              Sparks Fly  6485               Enchanted         16
# 2   3  Everything Has Changed  3942             Begin Again         42
# 3   4             Begin Again  3400     If This Was A Movie        218
# 4   5             Treacherous  2715             Treacherous         63
# 5   6             I Almost Do  2493                 I'd Lie        207
# 6   7        Back To December  2453             I Almost Do        117
# 7   8     If This Was A Movie  2434  Everything Has Changed        130
# 8   9              Love Story  1965                Fearless         41
# 9  10                Fearless  1962                Superman        220
#
#        RS_top_10
# 0   All Too Well
# 1  New Romantics
# 2     mirrorball
# 3       Delicate
# 4         august
# 5      Long Live
# 6          Lover
# 7    Blank Space
# 8        majorie
# ...

# %%
taylor_top_10.to_csv('5_taylor_top_10.csv', index=False)
